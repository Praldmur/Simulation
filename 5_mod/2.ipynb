# %%
import pandas as pd
from scipy import special as sp

# %%
n = 8
k = 0
c = sp.comb(n, k)
print(c)
# Out:
# 1.0

# %%
p_1 = 0.3
p_2 = 0.6

# %%
x = p_1**8*c
y = p_1**8*c

print(x)
# Out:
# 6.560999999999998e-05

# %%
=0.0005248799999999998+

# %%
x = 0.3**8
y=1-x
print(y)
# Out:
# 0.9222400000000001

# %%
x = 0.3**8
print(x)
# Out:
# 6.560999999999998e-05
