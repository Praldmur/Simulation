# %%
import nbformat

merged = None

for nb_name in [
    r"C:\Simulation\2_mod\2m_lesson_1.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_1.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_2.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_2.ipynb",
    r"C:\Simulation\2_mod\2m_project_2.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_3.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_3.ipynb",
    r"C:\Simulation\2_mod\2m_project_3.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_4_1.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_4.ipynb",
    r"C:\Simulation\2_mod\2m_project_4.ipynb",
    r"C:\Simulation\2_mod\2m_project_4_2.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_5.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_5.ipynb",
    r"C:\Simulation\2_mod\2m_project_5.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_6.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_6.ipynb",
    r"C:\Simulation\2_mod\2m_project_6.ipynb",
    r"C:\Simulation\2_mod\2m_project_6_2.ipynb",
    r"C:\Simulation\2_mod\2m_lesson_7.ipynb",
    r"C:\Simulation\2_mod\2m_notebook_7.ipynb",
    r"C:\Simulation\2_mod\2m_project_7.ipynb",
]:
    nb = nbformat.read(nb_name, as_version=4)
    if merged is None:
        merged = nb
    else:
        merged.cells.extend(nb.cells)

nbformat.write(merged, r"C:\Simulation\2_mod\merged.ipynb")
